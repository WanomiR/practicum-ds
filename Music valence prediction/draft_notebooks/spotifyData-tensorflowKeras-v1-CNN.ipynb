# %% [markdown]
# # Music Valence Prediction
#
# Spotify data | Tensorflow Keras | Convolutional Neural Network

# %% [markdown]
# ***

# %% [markdown]
# ## Project descritption

# %% [markdown]
# ### The problem

# %% [markdown]
# The main task of this project is to develop a python-based module to predict valence of newly released pop songs.
#
# *Valence* is a measure from 0.0 to 1.0 describing the musical positiveness conveyed by a track. Tracks with high valence sound more positive (e.g. happy, cheerful, euphoric), while tracks with low valence sound more negative (e.g. sad, depressed, angry).

# %% [markdown]
# ### The dataset

# %% [markdown]
# In this version of the project, Spotify data will be used: audio features and 30-second audio previews, available with the `spotify` library.

# %% [markdown]
# ### Audio features

# %% [markdown]
# The approach of the following research paper will be implemented: [Music Mood Classification using Convolutional Neural Networks](https://ccrma.stanford.edu/~jansto/documents/EmotionRecognition_Paper.pdf), with Mel-Spectrogram as the only audio feature being used.

# %% [markdown]
# ### Music attributes

# %% [markdown]
# In addition, the most related to this task music attributes will be explored:
#
# - *Tempo:* The tempo of the song. The overall estimated tempo of a track in beats per minute (BPM). In musical terminology, the tempo is the speed or pace of a given piece and derives directly from the average beat duration.
#
# - *Energy:* a measure from 0.0 to 1.0 and represents a perceptual measure of intensity and activity. Typically, energetic tracks feel fast, loud, and noisy. Higher the value more energetic the song.
#
# - *Danceability:* describes how suitable a track is for dancing based on a combination of musical elements including tempo, rhythm stability, beat strength, and overall regularity. The value ranges from 0 to 1. Higher the value more suitable the song is for dancing.
#
# - *Loudness:* Loudness values are averaged across the entire track. It is the quality of a song. It ranges from -60 to 0 DB. Higher the value, the louder the song.
#
# **the attributes description is taken from the article on Medium: [Spotify Music Data Analysis: Part 3](https://medium.com/analytics-vidhya/spotify-music-data-analysis-part-3-9097829df16e)*

# %% [markdown]
# ***

# %% [markdown]
# ## Imports and settings

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import librosa
import librosa.display as lib_display
import IPython.display as ipy_display

from tqdm import tqdm

from sklearn.model_selection import train_test_split

from keras.models import Sequential
from keras.layers import Conv2D, MaxPool2D, Flatten, Dense, BatchNormalization, Dropout
from keras.optimizers import Adam
from keras.regularizers import L1L2
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

# %%
plt.style.use("seaborn-v0_8")
sns.set_style("dark", {"axes.facecolor":"0.95"})
sns.set_palette("cubehelix")

plt.rcParams["figure.figsize"] = (9, 4)
# %config InlineBackend.figure_format = "retina"

# %%
seed = 490276

# %% [markdown]
# ***

# %% [markdown]
# ## EDA

# %% [markdown]
# ### Read the data

# %%
data = pd.read_csv("spotify_data/songs_data.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6800 entries, 0 to 6799
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   artist           6800 non-null   object
#  1   artist_uri       6800 non-null   object
#  2   track_name       6800 non-null   object
#  3   track_id         6800 non-null   object
#  4   track_uri        6800 non-null   object
#  5   preview_url      6800 non-null   object
#  6   tempo            6800 non-null   float64
#  7   energy           6800 non-null   float64
#  8   danceability     6800 non-null   float64
#  9   loudness         6800 non-null   float64
#  10  valence          6800 non-null   float64
#  11  local_file_path  6800 non-null   object
# dtypes: float64(5), object(7)
# memory usage: 637.6+ KB

# %% [markdown]
# ### Features relation

# %% [markdown]
# Look at how the features of music (attributes) are related to each other.

# %%
atr_cols = ["tempo","energy","danceability","loudness","valence"]
sns.pairplot(data[atr_cols]);

# %% [markdown]
# All feature values have a natural, normal distribution. Some features seem to be correlated, but it's difficult to say from the scatter plots.

# %%
corr_matrix = data[atr_cols].corr().round(2)
sns.heatmap(corr_matrix, annot=True);

# %% [markdown]
# The target feature, *valence*, is most correlated with with *danceability* and *energy*, although not significant enough to derive one from the other. The most correlated features are *loudness* and *energy*.

# %% [markdown]
# ### Genres

# %% [markdown]
# <mark>TBD...</mark>

# %% [markdown]
# ***

# %% [markdown]
# ## Features Extraction

# %% [markdown]
# The audio files need to be converted to mono and then resampled with a Sampling Frequency fs = 16000 Hz to save computing time.

# %% [markdown]
# ### Procedure

# %%
# select an arbitrary song from the dataset
rand_idx = np.random.randint(0, data.shape[0])
arb_song = data.loc[rand_idx,:]
file_path = arb_song["local_file_path"]

# load the audio file and resample
y, sr = librosa.load(file_path)
y = librosa.resample(y, orig_sr=sr, target_sr=16000)

# obtain melspectogram with 128 freq. bins
mel_spec = librosa.feature.melspectrogram(y=y, sr=16000, n_mels=128)
mel_spec = librosa.power_to_db(mel_spec, ref=np.max)

# show the resulting spectogram
librosa.display.specshow(mel_spec, y_axis='mel', x_axis='time')
plt.title("Mel Cpectrogram for the file {}".format(arb_song["track_name"]));
plt.colorbar(format='%+2.0f dB');

print("Estimated valence: ", arb_song["valence"])
ipy_display.Audio(file_path)
# Out:
# Estimated valence:  0.169
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Extract features

# %%
# features = []

# for i in tqdm(range(data.shape[0])):
    
#     track_id = data.loc[i, "track_id"]
#     file_path = data.loc[i,"local_file_path"]

#     # load the audio file and resample
#     y, sr = librosa.load(file_path, duration=25)
#     y = librosa.resample(y, orig_sr=sr, target_sr=16000)
    
#     # normalize from -1 to 1
#     y = librosa.util.normalize(y)

#     # obtain melspectogram with 128 freq. bins
#     mel_spec = librosa.feature.melspectrogram(y=y, sr=16000, n_mels=128)
#     mel_spec = librosa.power_to_db(mel_spec, ref=np.max)
    
#     # save extracted feature to the local directory
#     np.savetxt("spotify_data/mel_spec_features/" + track_id + ".csv",
#                mel_spec, delimiter=",")
    
#     # append to the features list
#     features.append(mel_spec)
# Out:
# 100%|█████████████████████████████████████| 6800/6800 [1:18:25<00:00,  1.45it/s]

# %%
# load fetures
features = []

for i in tqdm(range(data.shape[0])):
    track_id = data.loc[i, "track_id"]
    feature = pd.read_csv(
        "spotify_data/mel_spec_features/" + track_id + ".csv", 
        index_col=0).values
    
    features.append(feature)

# %%
# convert to an array
features = np.array(features)
features.shape
# Out:
# (6800, 128, 782)

# %% [markdown]
# ### Split the data

# %%
# bring the valence values on the scale from 0 to 10
data["valence"] = (data["valence"] * 10).round(2)

# %%
X = features
y = data["valence"].values

X_, X_test, y_, y_test = train_test_split(X, y, test_size=.1, 
                                          random_state=seed)

X_train, X_valid, y_train, y_valid = train_test_split(X_, y_, test_size=.2,
                                                      random_state=seed)

print(X_train.shape)
print(X_valid.shape)
print(X_test.shape)
# Out:
# (4896, 128, 782)
# (1224, 128, 782)
# (680, 128, 782)

# %% [markdown]
# ***

# %% [markdown]
# ## Model training

# %%
model = Sequential()
optimizer = Adam(learning_rate=0.001)
regularizer = L1L2(l1=0.001, l2=0.01)

model.add(Conv2D(filters=16, kernel_size=(3,3),
                 input_shape=(128, 782, 1), activation="relu"))
model.add(MaxPool2D(pool_size=(3,3)))
model.add(Flatten())
model.add(Dense(8, activation="relu", kernel_regularizer=regularizer))
model.add(BatchNormalization())
model.add(Dropout(.1))
model.add(Dense(1))

model.compile(
    loss="mean_squared_error",
    metrics=["mean_absolute_error"],
    optimizer=optimizer
)

# %%
checkpoints = ModelCheckpoint(filepath=f"saved_models/spotify_6800songs.hdf5",
                              verbose=1, save_best_only=True)

# initialize callbacks
earlystop = EarlyStopping(patience=10)
learn_rate_reduce = ReduceLROnPlateau(monitor="val_mean_absolute_error",
                                     patience=5,
                                     verbose=1,
                                     factor=.5,
                                     min_lr=.00001)

# %%
# fit the model
model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    epochs=50,
    # batch_size=batch_size,
    callbacks=[checkpoints, earlystop, learn_rate_reduce],
    verbose=1
)
# Out:
# Epoch 1/50
# 2023-01-01 11:08:37.933593: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 152/153 [============================>.] - ETA: 0s - loss: 32.5449 - mean_absolute_error: 4.9171
# 2023-01-01 11:08:46.468810: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Epoch 1: val_loss improved from inf to 21.93672, saving model to saved_models/spotify_6800songs.hdf5
# 153/153 [==============================] - 10s 58ms/step - loss: 32.4864 - mean_absolute_error: 4.9115 - val_loss: 21.9367 - val_mean_absolute_error: 3.7805 - lr: 0.0010
# Epoch 2/50
# 153/153 [==============================] - ETA: 0s - loss: 21.5590 - mean_absolute_error: 3.8207
# Epoch 2: val_loss did not improve from 21.93672
# 153/153 [==============================] - 8s 51ms/step - loss: 21.5590 - mean_absolute_error: 3.8207 - val_loss: 43.1196 - val_mean_absolute_error: 6.0169 - lr: 0.0010
# Epoch 3/50
# 152/153 [============================>.] - ETA: 0s - loss: 12.1587 - mean_absolute_error: 2.5176
# Epoch 3: val_loss did not improve from 21.93672
# 153/153 [==============================] - 7s 48ms/step - loss: 12.1227 - mean_absolute_error: 2.5107 - val_loss: 31.0086 - val_mean_absolute_error: 4.9284 - lr: 0.0010
# Epoch 4/50
# 152/153 [============================>.] - ETA: 0s - loss: 7.2734 - mean_absolute_error: 1.5837
# Epoch 4: val_loss improved from 21.93672 to 8.08595, saving model to saved_models/spotify_6800songs.hdf5
# 153/153 [==============================] - 7s 49ms/step - loss: 7.2752 - mean_absolute_error: 1.5840 - val_loss: 8.0859 - val_mean_absolute_error: 1.7226 - lr: 0.0010
# Epoch 5/50
# 152/153 [============================>.] - ETA: 0s - loss: 7.3638 - mean_absolute_error: 1.2684
# Epoch 5: val_loss did not improve from 8.08595
# 153/153 [==============================] - 7s 48ms/step - loss: 7.3685 - mean_absolute_error: 1.2688 - val_loss: 16.6673 - val_mean_absolute_error: 2.9544 - lr: 0.0010
# Epoch 6/50
# 153/153 [==============================] - ETA: 0s - loss: 7.3263 - mean_absolute_error: 1.2486
# Epoch 6: val_loss did not improve from 8.08595
# 153/153 [==============================] - 8s 50ms/step - loss: 7.3263 - mean_absolute_error: 1.2486 - val_loss: 13.2059 - val_mean_absolute_error: 2.4676 - lr: 0.0010
# Epoch 7/50
# 153/153 [==============================] - ETA: 0s - loss: 6.8013 - mean_absolute_error: 1.2128
# Epoch 7: val_loss did not improve from 8.08595
# 153/153 [==============================] - 7s 48ms/step - loss: 6.8013 - mean_absolute_error: 1.2128 - val_loss: 11.7924 - val_mean_absolute_error: 2.2979 - lr: 0.0010
# Epoch 8/50
# 153/153 [==============================] - ETA: 0s - loss: 7.8570 - mean_absolute_error: 1.2224
# Epoch 8: val_loss did not improve from 8.08595
# 153/153 [==============================] - 8s 49ms/step - loss: 7.8570 - mean_absolute_error: 1.2224 - val_loss: 15.8729 - val_mean_absolute_error: 2.8145 - lr: 0.0010
# Epoch 9/50
# 152/153 [============================>.] - ETA: 0s - loss: 6.7197 - mean_absolute_error: 1.1235
# Epoch 9: val_loss did not improve from 8.08595
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 153/153 [==============================] - 7s 49ms/step - loss: 6.7226 - mean_absolute_error: 1.1256 - val_loss: 11.7990 - val_mean_absolute_error: 2.2662 - lr: 0.0010
# Epoch 10/50
# 153/153 [==============================] - ETA: 0s - loss: 5.7437 - mean_absolute_error: 1.0639
# Epoch 10: val_loss did not improve from 8.08595
# 153/153 [==============================] - 7s 49ms/step - loss: 5.7437 - mean_absolute_error: 1.0639 - val_loss: 8.4716 - val_mean_absolute_error: 1.7744 - lr: 5.0000e-04
# Epoch 11/50
# 153/153 [==============================] - ETA: 0s - loss: 4.9911 - mean_absolute_error: 0.9564
# Epoch 11: val_loss improved from 8.08595 to 7.02682, saving model to saved_models/spotify_6800songs.hdf5
# 153/153 [==============================] - 8s 49ms/step - loss: 4.9911 - mean_absolute_error: 0.9564 - val_loss: 7.0268 - val_mean_absolute_error: 1.5551 - lr: 5.0000e-04
# Epoch 12/50
# 153/153 [==============================] - ETA: 0s - loss: 4.6910 - mean_absolute_error: 0.9503
# Epoch 12: val_loss did not improve from 7.02682
# 153/153 [==============================] - 7s 49ms/step - loss: 4.6910 - mean_absolute_error: 0.9503 - val_loss: 22.5879 - val_mean_absolute_error: 4.0088 - lr: 5.0000e-04
# Epoch 13/50
# 153/153 [==============================] - ETA: 0s - loss: 4.5818 - mean_absolute_error: 0.9954
# Epoch 13: val_loss improved from 7.02682 to 6.95489, saving model to saved_models/spotify_6800songs.hdf5
# 153/153 [==============================] - 7s 49ms/step - loss: 4.5818 - mean_absolute_error: 0.9954 - val_loss: 6.9549 - val_mean_absolute_error: 1.6241 - lr: 5.0000e-04
# Epoch 14/50
# 153/153 [==============================] - ETA: 0s - loss: 4.3347 - mean_absolute_error: 0.9749
# Epoch 14: val_loss improved from 6.95489 to 6.42399, saving model to saved_models/spotify_6800songs.hdf5
# 153/153 [==============================] - 7s 48ms/step - loss: 4.3347 - mean_absolute_error: 0.9749 - val_loss: 6.4240 - val_mean_absolute_error: 1.5617 - lr: 5.0000e-04
# Epoch 15/50
# 153/153 [==============================] - ETA: 0s - loss: 4.1086 - mean_absolute_error: 0.9521
# Epoch 15: val_loss improved from 6.42399 to 6.15658, saving model to saved_models/spotify_6800songs.hdf5
# 153/153 [==============================] - 7s 48ms/step - loss: 4.1086 - mean_absolute_error: 0.9521 - val_loss: 6.1566 - val_mean_absolute_error: 1.5431 - lr: 5.0000e-04
# Epoch 16/50
# 152/153 [============================>.] - ETA: 0s - loss: 4.0695 - mean_absolute_error: 0.9790
# Epoch 16: val_loss did not improve from 6.15658
# 153/153 [==============================] - 7s 48ms/step - loss: 4.0714 - mean_absolute_error: 0.9796 - val_loss: 18.9825 - val_mean_absolute_error: 3.6363 - lr: 5.0000e-04
# Epoch 17/50
# 152/153 [============================>.] - ETA: 0s - loss: 3.9187 - mean_absolute_error: 0.9679
# Epoch 17: val_loss did not improve from 6.15658
# 153/153 [==============================] - 8s 50ms/step - loss: 3.9161 - mean_absolute_error: 0.9673 - val_loss: 6.6736 - val_mean_absolute_error: 1.6799 - lr: 5.0000e-04
# Epoch 18/50
# 153/153 [==============================] - ETA: 0s - loss: 3.6645 - mean_absolute_error: 0.9393
# Epoch 18: val_loss did not improve from 6.15658
# 153/153 [==============================] - 8s 49ms/step - loss: 3.6645 - mean_absolute_error: 0.9393 - val_loss: 6.6904 - val_mean_absolute_error: 1.7354 - lr: 5.0000e-04
# Epoch 19/50
# 153/153 [==============================] - ETA: 0s - loss: 3.6818 - mean_absolute_error: 0.9618
# Epoch 19: val_loss did not improve from 6.15658
# 153/153 [==============================] - 8s 49ms/step - loss: 3.6818 - mean_absolute_error: 0.9618 - val_loss: 10.8080 - val_mean_absolute_error: 2.4992 - lr: 5.0000e-04
# Epoch 20/50
# 153/153 [==============================] - ETA: 0s - loss: 3.5465 - mean_absolute_error: 0.9588
# Epoch 20: val_loss did not improve from 6.15658
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 153/153 [==============================] - 8s 53ms/step - loss: 3.5465 - mean_absolute_error: 0.9588 - val_loss: 6.4241 - val_mean_absolute_error: 1.7015 - lr: 5.0000e-04
# Epoch 21/50
# 153/153 [==============================] - ETA: 0s - loss: 3.1609 - mean_absolute_error: 0.8914
# Epoch 21: val_loss did not improve from 6.15658
# 153/153 [==============================] - 8s 50ms/step - loss: 3.1609 - mean_absolute_error: 0.8914 - val_loss: 7.4150 - val_mean_absolute_error: 1.9632 - lr: 2.5000e-04
# Epoch 22/50
# 153/153 [==============================] - ETA: 0s - loss: 2.7607 - mean_absolute_error: 0.8083
# Epoch 22: val_loss improved from 6.15658 to 5.09296, saving model to saved_models/spotify_6800songs.hdf5
# 153/153 [==============================] - 8s 50ms/step - loss: 2.7607 - mean_absolute_error: 0.8083 - val_loss: 5.0930 - val_mean_absolute_error: 1.5048 - lr: 2.5000e-04
# Epoch 23/50
# 152/153 [============================>.] - ETA: 0s - loss: 2.6341 - mean_absolute_error: 0.7881
# Epoch 23: val_loss did not improve from 5.09296
# 153/153 [==============================] - 7s 48ms/step - loss: 2.6341 - mean_absolute_error: 0.7878 - val_loss: 5.1376 - val_mean_absolute_error: 1.5099 - lr: 2.5000e-04
# Epoch 24/50
# 152/153 [============================>.] - ETA: 0s - loss: 2.5994 - mean_absolute_error: 0.8025
# Epoch 24: val_loss did not improve from 5.09296
# 153/153 [==============================] - 8s 49ms/step - loss: 2.6002 - mean_absolute_error: 0.8032 - val_loss: 7.8064 - val_mean_absolute_error: 2.0729 - lr: 2.5000e-04
# Epoch 25/50
# 152/153 [============================>.] - ETA: 0s - loss: 2.6055 - mean_absolute_error: 0.8258
# Epoch 25: val_loss did not improve from 5.09296
# 153/153 [==============================] - 7s 49ms/step - loss: 2.6075 - mean_absolute_error: 0.8265 - val_loss: 5.2423 - val_mean_absolute_error: 1.5608 - lr: 2.5000e-04
# Epoch 26/50
# 152/153 [============================>.] - ETA: 0s - loss: 2.5573 - mean_absolute_error: 0.8146
# Epoch 26: val_loss did not improve from 5.09296
# 153/153 [==============================] - 8s 50ms/step - loss: 2.5548 - mean_absolute_error: 0.8138 - val_loss: 6.8610 - val_mean_absolute_error: 1.9164 - lr: 2.5000e-04
# Epoch 27/50
# 153/153 [==============================] - ETA: 0s - loss: 3.0193 - mean_absolute_error: 0.8987
# Epoch 27: val_loss did not improve from 5.09296
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 153/153 [==============================] - 8s 50ms/step - loss: 3.0193 - mean_absolute_error: 0.8987 - val_loss: 56.3107 - val_mean_absolute_error: 7.1030 - lr: 2.5000e-04
# Epoch 28/50
# 153/153 [==============================] - ETA: 0s - loss: 3.1884 - mean_absolute_error: 0.9040
# Epoch 28: val_loss did not improve from 5.09296
# 153/153 [==============================] - 8s 49ms/step - loss: 3.1884 - mean_absolute_error: 0.9040 - val_loss: 5.3547 - val_mean_absolute_error: 1.5521 - lr: 1.2500e-04
# Epoch 29/50
# 153/153 [==============================] - ETA: 0s - loss: 2.8457 - mean_absolute_error: 0.8400
# Epoch 29: val_loss did not improve from 5.09296
# 153/153 [==============================] - 8s 49ms/step - loss: 2.8457 - mean_absolute_error: 0.8400 - val_loss: 10.2260 - val_mean_absolute_error: 2.4703 - lr: 1.2500e-04
# Epoch 30/50
# 152/153 [============================>.] - ETA: 0s - loss: 2.6971 - mean_absolute_error: 0.8148
# Epoch 30: val_loss did not improve from 5.09296
# 153/153 [==============================] - 7s 48ms/step - loss: 2.6963 - mean_absolute_error: 0.8148 - val_loss: 5.4709 - val_mean_absolute_error: 1.6075 - lr: 1.2500e-04
# Epoch 31/50
# 152/153 [============================>.] - ETA: 0s - loss: 2.6595 - mean_absolute_error: 0.8289
# Epoch 31: val_loss did not improve from 5.09296
# 153/153 [==============================] - 8s 50ms/step - loss: 2.6587 - mean_absolute_error: 0.8296 - val_loss: 5.4667 - val_mean_absolute_error: 1.6158 - lr: 1.2500e-04
# Epoch 32/50
# 152/153 [============================>.] - ETA: 0s - loss: 2.6001 - mean_absolute_error: 0.8153
# Epoch 32: val_loss did not improve from 5.09296
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 153/153 [==============================] - 8s 49ms/step - loss: 2.6000 - mean_absolute_error: 0.8159 - val_loss: 5.2651 - val_mean_absolute_error: 1.5868 - lr: 1.2500e-04
