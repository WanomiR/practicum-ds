# %% [markdown]
# # Music Valence Prediction
# DAEM dataset | Tensorflow Keras | Convolutional Neural Network

# %% [markdown]
# ***

# %% [markdown]
# ## Project Description

# %% [markdown]
# ### The Objective

# %% [markdown]
# The goal of this task is to develop a Python-based module to predict the valence of newly released pop songs.   Two approaches are to use as an input:
# 1) the audio data (e.g. `.wav` files)
# 2) the songs lyrics
#
# Publicly available datasets can be used for training and testing.

# %% [markdown]
# ### Audio Features
# <a id="audio-features"></a>

# %% [markdown]
# This version of the project implements the approach of the following research paper: [Muic Mood Classification using Convolutional Neural Networks](https://ccrma.stanford.edu/~jansto/documents/EmotionRecognition_Paper.pdf)
# The only audio feature that will be used is the Mel-Spectrogram.

# %% [markdown]
# ### The Dataset

# %% [markdown]
# For this task the [DEAM dataset](https://cvml.unige.ch/databases/DEAM/) will be used.

# %% [markdown]
# ***

# %% [markdown]
# ## Libraries and settings

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns

import librosa
import librosa.display
import IPython.display as ipd

from tqdm import tqdm
from sklearn.model_selection import train_test_split

# %%
# set up some parameters for plots in this notebook
plt.style.use("seaborn-v0_8-paper")
sns.set_style("dark", {"axes.facecolor": ".95"})
sns.set_palette("cubehelix")
sns.set_context("notebook")

plt.rcParams["figure.figsize"] = (10, 4)
# %config InlineBackend.figure_format = "retina"

# %%
# save the random state number in advance
seed = 12345

# %% [markdown]
# ***

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ### Annotations data

# %%
# read the annotations file
annot = pd.read_csv("datasets/static_annotations_averaged_songs_1_2000.csv")

# %%
# show general info
annot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1744 entries, 0 to 1743
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   song_id        1744 non-null   int64
#  1    valence_mean  1744 non-null   float64
#  2    valence_std   1744 non-null   float64
#  3    arousal_mean  1744 non-null   float64
#  4    arousal_std   1744 non-null   float64
# dtypes: float64(4), int64(1)
# memory usage: 68.2 KB

# %%
# print several random rows
annot.sample(3)
# Out:
#       song_id   valence_mean   valence_std   arousal_mean   arousal_std
# 1403     1660            5.2          1.47            5.5          1.43
# 1692     1949            2.2          1.54            5.1          2.59
# 517       668            5.0          1.55            5.3          1.62

# %% [markdown]
# The column names contain "mean" and "std" due to the labeling procedure: each song has been labeled by 10 people. The average value of all rates was then taken and the standard deviation was calculated. For this project, this information is not needed.

# %%
# the column names contain empty spaces, fix that
annot.columns = [col.replace(" ","") for col in annot.columns]

# %%
# drop extra columns
annot.drop(columns=["valence_std","arousal_std"], inplace=True)
# shortent the column names
annot.rename(columns={"valence_mean":"valence", "arousal_mean":"arousal"}, inplace=True)
annot.sample(3)
# Out:
#       song_id  valence  arousal
# 1106     1363      5.1      3.6
# 596       769      6.2      5.0
# 1172     1429      3.0      2.3

# %% [markdown]
# ### Metadata

# %%
# read the meatdata file
meta = pd.read_csv("datasets/metadata_1_2000.csv")

# %%
# show general info
meta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1744 entries, 0 to 1743
# Data columns (total 7 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   song_id                         1744 non-null   int64
#  1   file_name                       744 non-null    object
#  2   Artist                          1744 non-null   object
#  3   Song title                      1744 non-null   object
#  4   start of the segment (min.sec)  1744 non-null   float64
#  5   end of the segment (min.sec)    1744 non-null   float64
#  6   Genre                           1744 non-null   object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 95.5+ KB

# %% [markdown]
# The reason the `file_name` column contains missing values is that this file was compiled from two (with the use of MS Excel) and the second of these files didn't have this information. However, the file names can be derived from the `song_id` column.

# %%
# print a sample of the meta set
meta.sample(3)
# Out:
#      song_id  file_name                               Artist  \
# 177      210  \t210.mp3  Advent Chamber Orchestra-Bughici \t
# 560      722  \t722.mp3                       Quantum Jazz\t
# 958     1215        NaN                     The Cracker Cats
#
#                                       Song title  \
# 177  \t Suite for Violin 8 Ardeleneascamoderato
# 560                \tOrbiting A Distant Planet\t
# 958                               We Plant Trees
#
#      start of the segment (min.sec)  end of the segment (min.sec)  \
# 177                        0.290000                       1.14000
# 560                        2.320000                       3.17000
# 958                       52.553764                     140.81254
#
#                 Genre
# 177     \tClassical\t
# 560          \tJazz\t
# 958  Country-Folk-Pop

# %% [markdown]
# The segment points are noted differently for the first 744 song, than it is for the second 100. However, it is known that each audio file in this dataset is 45 seconds length.

# %%
# tidy up the column names
meta.columns = ["song_id","file_name","artist","song_title","segment_start","segment_end", "genre"]
# fill in missing song titles
meta["song_title"].fillna("unknown", inplace=True)

# %%
# remove artifacts
for col in ["artist","song_title","genre"]:
    meta[col] = [re.sub(r"\t", "", string) for string in meta[col]]

# constract new file_name column
meta["file_name"] = meta["song_id"].astype(str) + ".mp3"

# print sample to check
meta.sample(3)
# Out:
#      song_id file_name         artist          song_title  segment_start  \
# 753     1010  1010.mp3  The Relatives            Bad Trip     172.742789
# 176      209   209.mp3  Kevin MacLeod  Amazing Grace 2011       0.210000
# 895     1152  1152.mp3  Lee Maddeford              Finale     226.922789
#
#      segment_end                           genre
# 753   268.400000               Blues-SoulRB-Rock
# 176     1.060000                       Classical
# 895   308.050045  Classical-International-Spoken

# %% [markdown]
# ### Merge datasets

# %%
data = annot.merge(meta, on="song_id",how="outer")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1744 entries, 0 to 1743
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   song_id        1744 non-null   int64
#  1   valence        1744 non-null   float64
#  2   arousal        1744 non-null   float64
#  3   file_name      1744 non-null   object
#  4   artist         1744 non-null   object
#  5   song_title     1744 non-null   object
#  6   segment_start  1744 non-null   float64
#  7   segment_end    1744 non-null   float64
#  8   genre          1744 non-null   object
# dtypes: float64(4), int64(1), object(4)
# memory usage: 136.2+ KB

# %% [markdown]
# ***

# %% [markdown]
# ## EDA

# %% [markdown]
# ### Valence vs arousal

# %%
# plot the valence and arousal values distribution
plt.scatter(data["valence"], data["arousal"], alpha=.3)
plt.title("Valence vs arousal scatter plot", fontsize=14)
plt.xlim([1,9])
plt.ylim([1,9])
plt.xlabel("Valence")
plt.ylabel("Arousal");

# %% [markdown]
# There is a noticeable general correlation between these values, which is expected.

# %% [markdown]
# ### Genre classes balance

# %%
# count the number of genres present in the dataset
nunique_genres = data["genre"].nunique()
print("Unique genres in the dataset:  {}\n".format(nunique_genres))

# select the top 10
top10_genres = data["genre"].value_counts()[:10]
top10_genres.loc["Other"] = data["genre"].value_counts()[10:].sum()

# plot a pie chart with genres ratio
plt.figure(figsize=(6,6))
labels = top10_genres.index
plt.pie(top10_genres, labels=labels)
plt.title("Proportion of genres in he dataset", fontsize=14);
# Out:
# Unique genres in the dataset:  126

# %% [markdown]
# The data contains a variety of music genres. Among the top-10 are present some genres related to this task: Pop, Hip-Hop, Rock, Pop-Rock, and Electronic.

# %% [markdown]
# ### Audio and waveform

# %%
random_idx = np.random.randint(0, 1744)

# select a reference song from the dataset
song = data.loc[random_idx, :]

# load the file and print its sampling rate 
file_path = "datasets/audio_files/" + song["file_name"]
y, sr = librosa.load(file_path, duration=30) # select only 30 seconds
# print info about this song
print(f"Sampling rate: {sr}")
print(song)

# plot the wavefrom
plt.figure(figsize=(12,4))
librosa.display.waveshow(y, sr=sr) # plot a waveform and play the file
plt.title(f'"{song.song_title[:15]}" by {song.artist}, {song.genre}')
plt.legend([f"song id {song.song_id}"])
plt.xlabel("Duration in seconds")

# output the audio
ipd.Audio(file_path)
# Out:
# Sampling rate: 22050
# song_id                                    1017
# valence                                     4.1
# arousal                                     3.8
# file_name                              1017.mp3
# artist                          James Beaudreau
# song_title                                 Hare
# segment_start                         36.395873
# segment_end                          122.162698
# genre            SoulRB-Blues-Experimental-Rock
# Name: 760, dtype: object
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Some songs don't sound like they belong to the genre with which they were associated. For example, [song 402](https://freemusicarchive.org/music/Patrick_Lee/Bad_Panda_42/Quittin_Time/) is way more funk than electronic, but it was marked as Electronic in the dataset, and [song 43](https://freemusicarchive.org/music/The_Agrarians/Uncomfortably_Songwriter_Vol_VI/Puritans_Too_1938/) can barely be described as Blues.

# %% [markdown]
# ***

# %% [markdown]
# ## Feature Preprocessing

# %% [markdown]
# The audio files need to be converted to mono and then resampled with a Sampling Frequency fs = 16000 Hz to save computing time. To avoid the association of loudness with emotion, all songs need to be normalized to a range from -1.0 to + 1.0. The songs are then converted to Mel-spectograms with the sample rate fs = 16000 Hz and a number of
# 80 bins. The Power is converted to db.

# %% [markdown]
# ### Procedure

# %%
# load the audio file and resample
y, sr = librosa.load(file_path, duration=30, mono=True)
y = librosa.resample(y, orig_sr=sr, target_sr=16000)

# normalize from -1 to 1
y = librosa.util.normalize(y)

# obtain melspectogram with 80 freq. bins
mel_spec = librosa.feature.melspectrogram(y=y, sr=16000, n_mels=80)
mel_spec = librosa.power_to_db(mel_spec, ref=np.max)

# %%
# show the resulting spectogram
librosa.display.specshow(mel_spec, y_axis='mel', x_axis='time')
plt.title("Mel Cpectrogram for the file {}".format(song.file_name));
plt.colorbar(format='%+2.0f dB');

# %% [markdown]
# ### Extract Features

# %%
# features = []

# for i in tqdm(range(len(data))):
    
#     file_name = data.loc[i, "file_name"]
#     file_path = "datasets/audio_files/" + file_name
    
#     y, sr = librosa.load(file_path, duration=30, mono=True)
#     y = librosa.resample(y, orig_sr=sr, target_sr=16000)

#     y = librosa.util.normalize(y)

#     mel_spec = librosa.feature.melspectrogram(y=y, sr=16000, n_mels=80)
#     mel_spec = librosa.power_to_db(mel_spec, ref=np.max)
    
#     features.append(mel_spec)
    
# features = np.array(features)
# Out:
#   0%|                                                  | 0/1744 [00:00<?, ?it/s]/Users/ioann/miniconda3/envs/tensorflow/lib/python3.9/site-packages/librosa/util/decorators.py:88: UserWarning: PySoundFile failed. Trying audioread instead.
#   return f(*args, **kwargs)
# 100%|███████████████████████████████████████| 1744/1744 [20:40<00:00,  1.41it/s]

# %%
# # save extracted feaures
# for i in tqdm(range(len(data))):
#     song_id = data.loc[i, "song_id"]
#     np.savetxt("datasets/mel_spec_features_2022-12-28/" + str(song_id) + ".csv", 
#                features[i], delimiter=",")
# Out:
# 100%|███████████████████████████████████████| 1744/1744 [00:48<00:00, 35.70it/s]

# %%
# load fetures
features = []

for i in tqdm(range(len(data))):
    song_id = data.loc[i, "song_id"]
    feature = pd.read_csv(
        "datasets/mel_spec_features_2022-12-28/" + str(song_id) + ".csv", 
        index_col=0).values
    
    features.append(feature)
    
features = np.array(features)
# Out:
# 100%|███████████████████████████████████████| 1744/1744 [00:31<00:00, 54.87it/s]

# %% [markdown]
# ### Split the data

# %%
X = features
y = data.valence.values

X_, X_test, y_, y_test = train_test_split(X, y, test_size=.2, random_state=seed)
X_train, X_valid, y_train, y_valid = train_test_split(X_, y_, test_size=.25, random_state=seed)

print(X_train.shape)
print(X_valid.shape)
print(X_test.shape)
# Out:
# (1046, 80, 938)
# (349, 80, 938)
# (349, 80, 938)

# %% [markdown]
# ***

# %% [markdown]
# ## Model training

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPool2D, Flatten, Dense, BatchNormalization, Dropout
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

# %%
# build the model
model = Sequential()
optimizer = Adam(learning_rate=0.01)

model.add(
    Conv2D(filters=16, kernel_size=(3, 3), 
           activation="relu", input_shape=(80, 938, 1))
)
model.add(MaxPool2D(pool_size=(3, 3)))
model.add(Flatten())
model.add(Dense(8, activation="relu"))
model.add(BatchNormalization())
model.add(Dropout(.2))
model.add(Dense(1))

model.compile(
    loss="mean_squared_error", 
    metrics=["mean_absolute_error"], 
    optimizer=optimizer
)

# %%
# train the model
num_epochs = 200
num_batch_size = 32

checkpointer = ModelCheckpoint(filepath="saved_models/valence_predicition.hdf5",
                              verbose=1, save_best_only=True)

# initialize callbacks
earlystop = EarlyStopping(patience=10)
learning_rate_reduction = ReduceLROnPlateau(monitor="val_mean_absolute_error", 
                                                patience=5, 
                                                verbose=1, 
                                                factor=0.5, 
                                                min_lr=0.00001)

# %%
# fit the model
model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    # batch_size=num_batch_size,
    epochs=num_epochs,
    callbacks=[checkpointer, earlystop, learning_rate_reduction],
    verbose=1
)
# Out:
# Epoch 1/200
# 2022-12-28 15:27:50.024936: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 33/33 [==============================] - ETA: 0s - loss: 18.2807 - mean_absolute_error: 4.0590
# 2022-12-28 15:27:51.591411: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Epoch 1: val_loss improved from inf to 3.28920, saving model to saved_models/valence_predicition.hdf5
# 33/33 [==============================] - 2s 50ms/step - loss: 18.2807 - mean_absolute_error: 4.0590 - val_loss: 3.2892 - val_mean_absolute_error: 1.4815 - lr: 0.0100
# Epoch 2/200
# 33/33 [==============================] - ETA: 0s - loss: 4.5065 - mean_absolute_error: 1.7426
# Epoch 2: val_loss did not improve from 3.28920
# 33/33 [==============================] - 1s 40ms/step - loss: 4.5065 - mean_absolute_error: 1.7426 - val_loss: 29.9391 - val_mean_absolute_error: 5.3134 - lr: 0.0100
# Epoch 3/200
# 33/33 [==============================] - ETA: 0s - loss: 1.7069 - mean_absolute_error: 1.0424
# Epoch 3: val_loss did not improve from 3.28920
# 33/33 [==============================] - 1s 39ms/step - loss: 1.7069 - mean_absolute_error: 1.0424 - val_loss: 15.2446 - val_mean_absolute_error: 3.7717 - lr: 0.0100
# Epoch 4/200
# 33/33 [==============================] - ETA: 0s - loss: 1.5327 - mean_absolute_error: 0.9914
# Epoch 4: val_loss did not improve from 3.28920
# 33/33 [==============================] - 1s 41ms/step - loss: 1.5327 - mean_absolute_error: 0.9914 - val_loss: 4.3893 - val_mean_absolute_error: 1.8999 - lr: 0.0100
# Epoch 5/200
# 33/33 [==============================] - ETA: 0s - loss: 1.2685 - mean_absolute_error: 0.8996
# Epoch 5: val_loss improved from 3.28920 to 1.13843, saving model to saved_models/valence_predicition.hdf5
# 33/33 [==============================] - 1s 41ms/step - loss: 1.2685 - mean_absolute_error: 0.8996 - val_loss: 1.1384 - val_mean_absolute_error: 0.8613 - lr: 0.0100
# Epoch 6/200
# 33/33 [==============================] - ETA: 0s - loss: 1.2591 - mean_absolute_error: 0.8878
# Epoch 6: val_loss improved from 1.13843 to 0.94117, saving model to saved_models/valence_predicition.hdf5
# 33/33 [==============================] - 1s 41ms/step - loss: 1.2591 - mean_absolute_error: 0.8878 - val_loss: 0.9412 - val_mean_absolute_error: 0.7818 - lr: 0.0100
# Epoch 7/200
# 33/33 [==============================] - ETA: 0s - loss: 1.1691 - mean_absolute_error: 0.8551
# Epoch 7: val_loss did not improve from 0.94117
# 33/33 [==============================] - 1s 40ms/step - loss: 1.1691 - mean_absolute_error: 0.8551 - val_loss: 1.1773 - val_mean_absolute_error: 0.8804 - lr: 0.0100
# Epoch 8/200
# 33/33 [==============================] - ETA: 0s - loss: 1.1544 - mean_absolute_error: 0.8630
# Epoch 8: val_loss did not improve from 0.94117
# 33/33 [==============================] - 1s 40ms/step - loss: 1.1544 - mean_absolute_error: 0.8630 - val_loss: 1.1042 - val_mean_absolute_error: 0.8710 - lr: 0.0100
# Epoch 9/200
# 33/33 [==============================] - ETA: 0s - loss: 1.2234 - mean_absolute_error: 0.8833
# Epoch 9: val_loss did not improve from 0.94117
# 33/33 [==============================] - 1s 39ms/step - loss: 1.2234 - mean_absolute_error: 0.8833 - val_loss: 0.9714 - val_mean_absolute_error: 0.8065 - lr: 0.0100
# Epoch 10/200
# 33/33 [==============================] - ETA: 0s - loss: 1.0818 - mean_absolute_error: 0.8358
# Epoch 10: val_loss did not improve from 0.94117
# 33/33 [==============================] - 1s 40ms/step - loss: 1.0818 - mean_absolute_error: 0.8358 - val_loss: 2.9492 - val_mean_absolute_error: 1.4660 - lr: 0.0100
# Epoch 11/200
# 33/33 [==============================] - ETA: 0s - loss: 1.3947 - mean_absolute_error: 0.9536
# Epoch 11: val_loss did not improve from 0.94117
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# 33/33 [==============================] - 1s 40ms/step - loss: 1.3947 - mean_absolute_error: 0.9536 - val_loss: 8.0859 - val_mean_absolute_error: 2.6335 - lr: 0.0100
# Epoch 12/200
# 33/33 [==============================] - ETA: 0s - loss: 1.4163 - mean_absolute_error: 0.9270
# Epoch 12: val_loss did not improve from 0.94117
# 33/33 [==============================] - 1s 39ms/step - loss: 1.4163 - mean_absolute_error: 0.9270 - val_loss: 1.3211 - val_mean_absolute_error: 0.9432 - lr: 0.0050
# Epoch 13/200
# 33/33 [==============================] - ETA: 0s - loss: 1.0746 - mean_absolute_error: 0.8312
# Epoch 13: val_loss did not improve from 0.94117
# 33/33 [==============================] - 1s 39ms/step - loss: 1.0746 - mean_absolute_error: 0.8312 - val_loss: 2.7871 - val_mean_absolute_error: 1.4190 - lr: 0.0050
# Epoch 14/200
# 33/33 [==============================] - ETA: 0s - loss: 0.9727 - mean_absolute_error: 0.7798
# Epoch 14: val_loss did not improve from 0.94117
# 33/33 [==============================] - 1s 40ms/step - loss: 0.9727 - mean_absolute_error: 0.7798 - val_loss: 2.1423 - val_mean_absolute_error: 1.2206 - lr: 0.0050
# Epoch 15/200
# 33/33 [==============================] - ETA: 0s - loss: 0.9408 - mean_absolute_error: 0.7591
# Epoch 15: val_loss did not improve from 0.94117
# 33/33 [==============================] - 1s 40ms/step - loss: 0.9408 - mean_absolute_error: 0.7591 - val_loss: 2.3838 - val_mean_absolute_error: 1.3016 - lr: 0.0050
# Epoch 16/200
# 33/33 [==============================] - ETA: 0s - loss: 0.8976 - mean_absolute_error: 0.7540
# Epoch 16: val_loss improved from 0.94117 to 0.93056, saving model to saved_models/valence_predicition.hdf5
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# 33/33 [==============================] - 1s 41ms/step - loss: 0.8976 - mean_absolute_error: 0.7540 - val_loss: 0.9306 - val_mean_absolute_error: 0.7874 - lr: 0.0050
# Epoch 17/200
# 33/33 [==============================] - ETA: 0s - loss: 0.8889 - mean_absolute_error: 0.7483
# Epoch 17: val_loss did not improve from 0.93056
# 33/33 [==============================] - 1s 40ms/step - loss: 0.8889 - mean_absolute_error: 0.7483 - val_loss: 2.8080 - val_mean_absolute_error: 1.4356 - lr: 0.0025
# Epoch 18/200
# 33/33 [==============================] - ETA: 0s - loss: 0.7590 - mean_absolute_error: 0.6882
# Epoch 18: val_loss did not improve from 0.93056
# 33/33 [==============================] - 1s 39ms/step - loss: 0.7590 - mean_absolute_error: 0.6882 - val_loss: 1.4174 - val_mean_absolute_error: 0.9775 - lr: 0.0025
# Epoch 19/200
# 33/33 [==============================] - ETA: 0s - loss: 0.7965 - mean_absolute_error: 0.7038
# Epoch 19: val_loss did not improve from 0.93056
# 33/33 [==============================] - 1s 39ms/step - loss: 0.7965 - mean_absolute_error: 0.7038 - val_loss: 1.0177 - val_mean_absolute_error: 0.8308 - lr: 0.0025
# Epoch 20/200
# 33/33 [==============================] - ETA: 0s - loss: 0.7469 - mean_absolute_error: 0.6815
# Epoch 20: val_loss improved from 0.93056 to 0.87061, saving model to saved_models/valence_predicition.hdf5
# 33/33 [==============================] - 1s 40ms/step - loss: 0.7469 - mean_absolute_error: 0.6815 - val_loss: 0.8706 - val_mean_absolute_error: 0.7659 - lr: 0.0025
# Epoch 21/200
# 33/33 [==============================] - ETA: 0s - loss: 0.6748 - mean_absolute_error: 0.6552
# Epoch 21: val_loss did not improve from 0.87061
# 33/33 [==============================] - 1s 40ms/step - loss: 0.6748 - mean_absolute_error: 0.6552 - val_loss: 1.2799 - val_mean_absolute_error: 0.9349 - lr: 0.0025
# Epoch 22/200
# 33/33 [==============================] - ETA: 0s - loss: 0.7258 - mean_absolute_error: 0.6627
# Epoch 22: val_loss did not improve from 0.87061
# 33/33 [==============================] - 1s 39ms/step - loss: 0.7258 - mean_absolute_error: 0.6627 - val_loss: 1.2324 - val_mean_absolute_error: 0.9183 - lr: 0.0025
# Epoch 23/200
# 33/33 [==============================] - ETA: 0s - loss: 0.6642 - mean_absolute_error: 0.6398
# Epoch 23: val_loss did not improve from 0.87061
# 33/33 [==============================] - 1s 40ms/step - loss: 0.6642 - mean_absolute_error: 0.6398 - val_loss: 0.8895 - val_mean_absolute_error: 0.7713 - lr: 0.0025
# Epoch 24/200
# 33/33 [==============================] - ETA: 0s - loss: 0.6216 - mean_absolute_error: 0.6219
# Epoch 24: val_loss did not improve from 0.87061
# 33/33 [==============================] - 1s 39ms/step - loss: 0.6216 - mean_absolute_error: 0.6219 - val_loss: 1.4188 - val_mean_absolute_error: 0.9926 - lr: 0.0025
# Epoch 25/200
# 33/33 [==============================] - ETA: 0s - loss: 0.6576 - mean_absolute_error: 0.6286
# Epoch 25: val_loss did not improve from 0.87061
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
# 33/33 [==============================] - 1s 39ms/step - loss: 0.6576 - mean_absolute_error: 0.6286 - val_loss: 0.9208 - val_mean_absolute_error: 0.7854 - lr: 0.0025
# Epoch 26/200
# 33/33 [==============================] - ETA: 0s - loss: 0.6168 - mean_absolute_error: 0.6193
# Epoch 26: val_loss did not improve from 0.87061
# 33/33 [==============================] - 1s 39ms/step - loss: 0.6168 - mean_absolute_error: 0.6193 - val_loss: 1.0174 - val_mean_absolute_error: 0.8351 - lr: 0.0012
# Epoch 27/200
# 33/33 [==============================] - ETA: 0s - loss: 0.5682 - mean_absolute_error: 0.5840
# Epoch 27: val_loss did not improve from 0.87061
# 33/33 [==============================] - 1s 39ms/step - loss: 0.5682 - mean_absolute_error: 0.5840 - val_loss: 1.0858 - val_mean_absolute_error: 0.8644 - lr: 0.0012
# Epoch 28/200
# 33/33 [==============================] - ETA: 0s - loss: 0.5456 - mean_absolute_error: 0.5792
# Epoch 28: val_loss did not improve from 0.87061
# 33/33 [==============================] - 1s 40ms/step - loss: 0.5456 - mean_absolute_error: 0.5792 - val_loss: 1.1253 - val_mean_absolute_error: 0.8780 - lr: 0.0012
# Epoch 29/200
# 33/33 [==============================] - ETA: 0s - loss: 0.5657 - mean_absolute_error: 0.5894
# Epoch 29: val_loss did not improve from 0.87061
# 33/33 [==============================] - 1s 39ms/step - loss: 0.5657 - mean_absolute_error: 0.5894 - val_loss: 1.0590 - val_mean_absolute_error: 0.8499 - lr: 0.0012
# Epoch 30/200
# 33/33 [==============================] - ETA: 0s - loss: 0.5626 - mean_absolute_error: 0.5943
# Epoch 30: val_loss did not improve from 0.87061
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.0006249999860301614.
# 33/33 [==============================] - 1s 39ms/step - loss: 0.5626 - mean_absolute_error: 0.5943 - val_loss: 1.3324 - val_mean_absolute_error: 0.9276 - lr: 0.0012
